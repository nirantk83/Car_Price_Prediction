# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
import warnings
warnings.filterwarnings('ignore')

# %%
c=pd.read_csv("cars.csv")
c
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
c.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#replace ? with np.nan

# %%
c['normalized-losses'].replace('?',np.nan,inplace=True)

# %%
c.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
#there are 41 null values 
#we have to handle this null value with central tendency

# %%
#if there are  null value then convert into float only

# %%
c['normalized-losses']=c['normalized-losses'].astype(float)

# %%
c.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
#us fillna to handle nullvalues

# %%
c['normalized-losses'].mean()
# Out:
# 122.0

# %%
c['normalized-losses'].fillna(c['normalized-losses'].mean(),inplace=True)

# %%
c.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# ...

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
#horsepower 
# replace ? with np.nan

# %%
c['horsepower'].replace('?',np.nan,inplace=True)

# %%
c['horsepower']=c['horsepower'].astype(float)

# %%
c.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#there are only 2 null values so we can drop

# %%
c.dropna(inplace=True)

# %%
c.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          203 non-null    int64
#  1   normalized-losses  203 non-null    float64
#  2   make               203 non-null    object
#  3   fuel-type          203 non-null    object
#  4   body-style         203 non-null    object
#  5   drive-wheels       203 non-null    object
#  6   engine-location    203 non-null    object
#  7   width              203 non-null    float64
#  8   height             203 non-null    float64
#  9   engine-type        203 non-null    object
#  10  engine-size        203 non-null    int64
#  11  horsepower         203 non-null    float64
#  12  city-mpg           203 non-null    int64
#  13  highway-mpg        203 non-null    int64
#  14  price              203 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
c.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  203.000000         203.000000  203.000000  203.000000   203.000000
# mean     0.832512         122.000000   65.901478   53.733498   126.857143
# std      1.247384          31.837458    2.154835    2.442864    41.845239
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000         101.000000   64.050000   52.000000    97.000000
# 50%      1.000000         122.000000   65.500000   54.100000   119.000000
# 75%      2.000000         137.000000   66.900000   55.500000   143.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  203.000000  203.000000   203.000000    203.000000
# mean   104.256158   25.241379    30.748768  13263.266010
# std     39.714369    6.570702     6.920406   7933.310625
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
#how to handle outliers

# %%
sea.boxplot(data=c,x='price')
plt.show()

# %%
c['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# plt.figure(figsize=(7,7))

# %%
plt.figure(figsize=(7,7))
sea.boxplot(data=c,x='price',y='make')
plt.show()

# %%
c.loc[(c['make']=='toyota') & (c['price']>13000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# ...

# %%
c.drop(index=[172,178,179,180,181],inplace=True)

# %%
plt.figure(figsize=(7,7))
sea.boxplot(data=c,x='price',y='make')
plt.show()

# %%
c.loc[(c['make']=='plymouth') & (c['price']>10000)]
# Out:
#      symboling  normalized-losses      make fuel-type body-style drive-wheels  \
# 124          3              122.0  plymouth       gas  hatchback          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 124           front   66.3    50.2         ohc          156       145.0
#
#      city-mpg  highway-mpg  price
# 124        19           24  12764

# %%
c.drop(index=[124],inplace=True)

# %%
c.loc[(c['make']=='mitsubishi') & (c['price']>12000)]
# Out:
#     symboling  normalized-losses        make fuel-type body-style  \
# 82          3              122.0  mitsubishi       gas  hatchback
# 83          3              122.0  mitsubishi       gas  hatchback
# 84          3              122.0  mitsubishi       gas  hatchback
#
#    drive-wheels engine-location  width  height engine-type  engine-size  \
# 82          fwd           front   66.3    50.2         ohc          156
# 83          fwd           front   66.3    50.2         ohc          156
# 84          fwd           front   66.3    50.2         ohc          156
#
#     horsepower  city-mpg  highway-mpg  price
# 82       145.0        19           24  12629
# 83       145.0        19           24  14869
# 84       145.0        19           24  14489

# %%
c.drop(index=[82,83,84],inplace=True)

# %%
c.loc[(c['make']=='isuzu') & (c['price']>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
c.drop(index=[45],inplace=True)

# %%
plt.figure(figsize=(7,7))
sea.boxplot(data=c,x='price',y='make')
plt.show()

# %%
c.loc[(c['make']=='honda') & (c['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
c.drop(index=[41],inplace=True)

# %%
c.loc[(c['make']=='dodge') & (c['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 29          3              145.0  dodge       gas  hatchback          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 29           front   66.3    50.2         ohc          156       145.0
#
#     city-mpg  highway-mpg  price
# 29        19           24  12964

# %%
c.drop(index=[29],inplace=True)

# %%
plt.figure(figsize=(7,7))
sea.boxplot(data=c,x='price',y='make')
plt.show()

# %%
df_num=c.select_dtypes(['int','float'])

# %%
df_cat=c.select_dtypes(object)

# %%
df_cat
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
#one hot encodinng

# %%
#pd.get_dummies(df_cat['make'])

# %%
#lable encoding

# %%
#import model
from sklearn.preprocessing import LabelEncoder
#init lable encoder
le=LabelEncoder()

#transfer output
c['Fuel-type']=le.fit_transform(c['fuel-type'])

# %%
for i in df_cat:
    le=LabelEncoder()
    df_cat[i]=le.fit_transform(df_cat[i])

# %%
df_cat
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# [191 rows x 6 columns]

# %%
df3=pd.concat([df_cat,df_num],axis=1) #concat two DF

# %%
df3
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type  \
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# ...

# %%
#skewness

# %%
#a=np.sqrt(c['price'])

# %%
#a.skew()

# %%
#Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit_transform(c[['width']])
# Out:
# array([[-0.81074779],
#        [-0.81074779],
#        [-0.17424174],
#        [ 0.14401128],
#        [ 0.23494071],
#        [ 0.189476  ],
#        [ 2.50817659],
#        [ 2.50817659],
#        [ 2.50817659],
#        [ 0.91691148],
#        [-0.49249477],
#        [-0.49249477],
#        [-0.49249477],
#        [-0.49249477],
#        [ 0.4622643 ],
#        [ 0.4622643 ],
#        [ 0.91691148],
#        [ 2.280853  ],
#        [-2.53840705],
#        [-1.03807138],
#        [-1.03807138],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.94714194],
#        [-0.5834242 ],
#        [-0.90167722],
#        [-0.90167722],
#        [-0.85621251],
#        [-0.85621251],
#        [-0.85621251],
#        [-0.85621251],
#        [-0.90167722],
#        [-0.3106359 ],
#        [-0.3106359 ],
#        [-0.3106359 ],
#        [-1.53818327],
#        [ 0.05308184],
# ...

# %%
#from sklearn.preprocessing import MinMaxScaler
#mn=MinMaxScaler()
#mn.fit_transform(c[['width']])

# %%
sea.pairplot(c)

# %%
df3
# Out:
#      make  fuel-type  body-style  drive-wheels  engine-location  engine-type  \
# 0       0          1           0             2                0            0
# 1       0          1           0             2                0            0
# 2       0          1           2             2                0            5
# 3       1          1           3             1                0            3
# 4       1          1           3             0                0            3
# ..    ...        ...         ...           ...              ...          ...
# 200    20          1           3             2                0            3
# 201    20          1           3             2                0            3
# 202    20          1           3             2                0            5
# 203    20          0           3             2                0            3
# 204    20          1           3             2                0            3
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y=df3["price"]
x=df3.iloc[:,:-1]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)
train=lr.score(xtrain,ytrain)
test=lr.score(xtest,ytest)
print(f"Training Accuracy = {train}")
print(f"Testing Accuracy = {test}")
# Out:
# Training Accuracy = 0.9048915140262364
# Testing Accuracy = 0.7640523333560649

# %%
make_in=int(input('enrter a manufactures details between o to 1'))
fuel_type=int(input('enrter type of fual'))
body_style=int(input('enter body style '))
drive_wheels=int(input('enter drive-wheels'))
engine_typee=int(input('enter engine-typee '))
engine_locations=int(input('enter engine-location '))
symboling=int(input('enter symboling'))
normalized_losses=int(input('enter  normalized-losses '))
width=int(input('enter width '))
height=int(input('enter height '))
engine_size=int(input('enter engine-size '))
horsepower=int(input('enter horsepowerv '))
city_mpg=int(input('enter city-mpg '))
highway_mpg=int(input('enter highway-mpg '))







res=lr.predict([[make_in,fuel_type,body_style,drive_wheels,engine_typee,engine_locations,symboling,normalized_losses,width,height,engine_size,horsepower,city_mpg,highway_mpg]])
print('PRICE OF CAR IS:',res,'RS ONLY')
# Out:
# enrter a manufactures details between o to 11
# enrter type of fual2
# enter body style 3
# enter drive-wheels4
# enter engine-typee 5
# enter engine-location 3
# enter symboling2
# enter  normalized-losses 100
# enter width 60
# enter height 60
# enter engine-size 100
# enter horsepowerv 100
# enter city-mpg 23
# enter highway-mpg 23
# PRICE OF CAR IS: [78886.16791046] RS ONLY

# %%
#import pickle
#with open('C:\\Users\Dell\AppData\Local\Programs\Python\Python39\CAR PRICE ML PROJECT\\model_pkl', 'wb') as files:
    #pickle.dump(lr, files)
